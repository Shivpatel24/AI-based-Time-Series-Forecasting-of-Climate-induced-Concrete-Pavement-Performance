# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

# Load CSV
file_path = '/home/bel/Desktop/Shiv_SRIP/ATenLoc/SARIMA/output_sarima.csv'  # Replace with your actual file path
df = pd.read_csv(file_path)

# Extract Actual and Predicted
y_true = df['Actual_TL']
y_pred = df['Predicted_TL']

# Calculate metrics
r2 = r2_score(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

print(f'R²: {r2:.4f}')
print(f'MAE: {mae:.4f}')
print(f'RMSE: {rmse:.4f}')

# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(y_true, y_pred, color='blue', alpha=0.6, label='Predictions')
plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], color='red', linestyle='--', label='Ideal Fit')
plt.xlabel('Numerical Model TL')
plt.ylabel('ML model TL')
plt.title('TL')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# R²: 0.5690
# MAE: 3.4011
# RMSE: 4.7980
# /tmp/ipykernel_3218628/2543585706.py:32: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /home/bel/Desktop/Shiv_SRIP/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# === Load your CSV file ===
csv_path = '/home/bel/Desktop/Shiv_SRIP/ATenLoc/SARIMA/output_sarimacesr.csv'  # 🔁 Update with your actual path
df = pd.read_csv(csv_path)

# === Clean the data ===
# Replace infinities with NaN and drop any invalid rows
df = df.replace([np.inf, -np.inf], np.nan).dropna(subset=['Actual_CESR', 'Predicted_CESR'])

# Keep only rows where both Actual and Predicted CESR are in [-1, 1]
df = df[(df['Actual_CESR'].between(-1, 1)) & (df['Predicted_CESR'].between(-1, 1))]

# Round predicted values to 4 decimals
df['Predicted_CESR'] = df['Predicted_CESR'].round(4)

# === Extract values ===
y_true = df['Actual_CESR'].values
y_pred = df['Predicted_CESR'].values

# === Debug: Check value ranges ===
print("Max Actual_CESR:", np.max(np.abs(y_true)))
print("Max Predicted_CESR:", np.max(np.abs(y_pred)))

# === Compute metrics ===
r2 = r2_score(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

print("\n--- Evaluation Metrics ---")
print(f"R² Score: {r2:.4f}")
print(f"MAE:      {mae:.4f}")
print(f"RMSE:     {rmse:.4f}")

# === Scatter Plot ===
plt.figure(figsize=(8, 6))
plt.scatter(y_true, y_pred, color='blue', alpha=0.6, label='Predictions')
plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], 'r--', label='Ideal Line')
plt.xlabel('Numerical Model CESR')
plt.ylabel(' SARIMAX model CESR ')
plt.title('CESR')
plt.grid(True)
plt.legend()
try:
    plt.tight_layout()
except Exception as e:
    print("tight_layout() failed:", e)
plt.show()
# Out:
# Max Actual_CESR: 0.5692
# Max Predicted_CESR: 0.8848
#
# --- Evaluation Metrics ---
# R² Score: 0.5932
# MAE:      0.0631
# RMSE:     0.0846
# /tmp/ipykernel_3218628/2659604077.py:48: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /home/bel/Desktop/Shiv_SRIP/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# SARIMAX

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# === Load your CSV file ===
csv_path = '/home/bel/Desktop/Shiv_SRIP/ATenLoc/SARIMA/output_sarimax_cesr.csv'  # 🔁 Update with your actual path
df = pd.read_csv(csv_path)

# === Clean the data ===
# Replace infinities with NaN and drop any invalid rows
df = df.replace([np.inf, -np.inf], np.nan).dropna(subset=['Actual_CESR', 'Predicted_CESR'])

# Keep only rows where both Actual and Predicted CESR are in [-1, 1]
df = df[(df['Actual_CESR'].between(-1, 1)) & (df['Predicted_CESR'].between(-1, 1))]

# Round predicted values to 4 decimals
df['Predicted_CESR'] = df['Predicted_CESR'].round(4)

# === Extract values ===
y_true = df['Actual_CESR'].values
y_pred = df['Predicted_CESR'].values

# === Debug: Check value ranges ===
print("Max Actual_CESR:", np.max(np.abs(y_true)))
print("Max Predicted_CESR:", np.max(np.abs(y_pred)))

# === Compute metrics ===
r2 = r2_score(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

print("\n--- Evaluation Metrics ---")
print(f"R² Score: {r2:.4f}")
print(f"MAE:      {mae:.4f}")
print(f"RMSE:     {rmse:.4f}")

# === Scatter Plot ===
plt.figure(figsize=(8, 6))
plt.scatter(y_true, y_pred, color='blue', alpha=0.6, label='Predictions')
plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], 'r--', label='Ideal Line')
plt.xlabel('Numerical Model CESR')
plt.ylabel(' SARIMAX model CESR ')
plt.title('CESR')
plt.grid(True)
plt.legend()
try:
    plt.tight_layout()
except Exception as e:
    print("tight_layout() failed:", e)
plt.show()
# Out:
# Max Actual_CESR: 0.5117
# Max Predicted_CESR: 0.4899
#
# --- Evaluation Metrics ---
# R² Score: 0.7479
# MAE:      0.0484
# RMSE:     0.0653
# /tmp/ipykernel_3218628/1576053553.py:48: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /home/bel/Desktop/Shiv_SRIP/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd

# Load the CSV
file_path = '/home/bel/Desktop/Shiv_SRIP/ATenLoc/SARIMA/output_sarimax.csv'  # Modify if needed
df = pd.read_csv(file_path)

# Remove rows with missing (NaN) Predicted_TL
df_cleaned = df.dropna(subset=['Predicted_TL'])

# Save back to the same file (or change filename to avoid overwrite)
df_cleaned.to_csv(file_path, index=False)

print(f"✅ Cleaned file saved to: {file_path}")
# Out:
# ✅ Cleaned file saved to: /home/bel/Desktop/Shiv_SRIP/ATenLoc/SARIMA/output_sarimax.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

# === Load CSV ===
file_path = '/home/bel/Desktop/Shiv_SRIP/ATenLoc/SARIMA/output_sarimax.csv'
df = pd.read_csv(file_path)

# === Clean the data ===
df = df.replace([np.inf, -np.inf], np.nan)                     # Replace infinities with NaN
df = df.dropna(subset=['Actual_TL', 'Predicted_TL'])          # Drop rows with NaNs

# Optional: Round predicted values
df['Predicted_TL'] = df['Predicted_TL'].round(4)

# === Take first 2 lakh rows only ===
df_sample = df.tail(200000)

# Extract values
y_true = df_sample['Actual_TL'].values
y_pred = df_sample['Predicted_TL'].values

# === Compute Metrics only on first 2 lakh rows ===
r2 = r2_score(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

print("\n--- SARIMAX Evaluation Metrics (First 2 Lakh Rows) ---")
print(f"R² Score: {r2:.4f}")
print(f"MAE:      {mae:.4f}")
print(f"RMSE:     {rmse:.4f}")

# === Scatter Plot (first 2 lakh rows only) ===
plt.figure(figsize=(8, 6))
plt.scatter(y_true, y_pred, color='blue', alpha=0.6, label='Predictions')
plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], 'r--', label='Ideal Fit')
plt.xlabel('Numerical Model TL')
plt.ylabel('SARIMAX Model TL')
plt.title('Actual vs Predicted TL ')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /home/bel/Desktop/Shiv_SRIP/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1920: RuntimeWarning: overflow encountered in multiply
#   values = self.values.round(decimals)  # type: ignore[union-attr]
# --- SARIMAX Evaluation Metrics (First 2 Lakh Rows) ---
# R² Score: 0.3145
# MAE:      4.8893
# RMSE:     6.9711
